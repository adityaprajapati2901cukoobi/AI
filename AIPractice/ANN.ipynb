# %%
import pandas as pd
data=pd.read_csv('data/iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X=data['SepalLengthCm']
y=data['SepalWidthCm']

X_train, X_test, y_train, y_test = train_test_split(X,y , random_state=104,test_size=0.25, shuffle=True)

# %%
import seaborn as sns
sns.pairplot(data,hue='Id')
# Out:
# c:\Users\adity\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()
y1=encoder.fit_transform(y_train)
x1=encoder.fit_transform(X_train)
X = pd.get_dummies(x1).values
y= pd.get_dummies(y1).values

# %%
from keras import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(10,activation='relu'))
model.add(Dense(20,activation='softmax'))
model.add(Dense(40,activation='tanh'))
model.compile()
model.evaluate(X_test,y_test)
# Out:
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0000e+00
# 0.0
